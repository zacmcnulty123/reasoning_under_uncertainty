# %%
import itertools
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
# create a BN
bayesnet=gum.fastBN("E<-C<-A->B->E->F;B->D;A->D");
# print the indepency model by testing d-separations

# how to iterate for each subset of an interable
def get_powerset(iterable):
    """
    powerset([1,2,3]) --> () (1,) (2,) (3,) (1,2) (1,3) (2,3) (1,2,3)
    """
    xs = list(iterable)
    # note we return an iterator rather than a list
    return itertools.chain.from_iterable(itertools.combinations(xs,n) for n in range(len(xs)+1))

# testing every d-separation
for i in bayesnet.names():
    for j in bayesnet.names()-{i}:
        for k in get_powerset(bayesnet.names()-{i,j}):
            if bayesnet.isIndependent(i,j,k):
                print(f"{i} indep {j} given {k}")
# Out:
# D indep C given ('A',)
# D indep C given ('A', 'B')
# D indep C given ('A', 'B', 'E')
# D indep C given ('A', 'B', 'F')
# D indep C given ('A', 'B', 'E', 'F')
# D indep F given ('E',)
# D indep F given ('A', 'B')
# D indep F given ('A', 'E')
# D indep F given ('B', 'E')
# D indep F given ('B', 'C')
# D indep F given ('E', 'C')
# D indep F given ('A', 'B', 'E')
# D indep F given ('A', 'B', 'C')
# D indep F given ('A', 'E', 'C')
# D indep F given ('B', 'E', 'C')
# D indep F given ('A', 'B', 'E', 'C')
# D indep E given ('A', 'B')
# D indep E given ('B', 'C')
# D indep E given ('A', 'B', 'C')
# D indep E given ('A', 'B', 'F')
# D indep E given ('B', 'C', 'F')
# D indep E given ('A', 'B', 'C', 'F')
# C indep D given ('A',)
# C indep D given ('A', 'B')
# C indep D given ('A', 'B', 'E')
# C indep D given ('A', 'B', 'F')
# C indep D given ('A', 'B', 'E', 'F')
# C indep F given ('E',)
# C indep F given ('A', 'E')
# C indep F given ('D', 'E')
# C indep F given ('E', 'B')
# C indep F given ('A', 'D', 'E')
# C indep F given ('A', 'E', 'B')
# C indep F given ('D', 'E', 'B')
# C indep F given ('A', 'D', 'E', 'B')
# C indep B given ('A',)
# C indep B given ('A', 'D')
# F indep D given ('E',)
# F indep D given ('A', 'B')
# F indep D given ('A', 'E')
# F indep D given ('B', 'E')
# F indep D given ('B', 'C')
# F indep D given ('E', 'C')
# F indep D given ('A', 'B', 'E')
# F indep D given ('A', 'B', 'C')
# F indep D given ('A', 'E', 'C')
# F indep D given ('B', 'E', 'C')
# F indep D given ('A', 'B', 'E', 'C')
# F indep C given ('E',)
# F indep C given ('A', 'E')
# F indep C given ('D', 'E')
# F indep C given ('E', 'B')
# F indep C given ('A', 'D', 'E')
# F indep C given ('A', 'E', 'B')
# F indep C given ('D', 'E', 'B')
# F indep C given ('A', 'D', 'E', 'B')
# F indep B given ('E',)
# F indep B given ('A', 'E')
# F indep B given ('D', 'E')
# F indep B given ('E', 'C')
# F indep B given ('A', 'D', 'E')
# F indep B given ('A', 'E', 'C')
# F indep B given ('D', 'E', 'C')
# F indep B given ('A', 'D', 'E', 'C')
# F indep A given ('E',)
# F indep A given ('D', 'E')
# F indep A given ('E', 'C')
# F indep A given ('E', 'B')
# F indep A given ('C', 'B')
# F indep A given ('D', 'E', 'C')
# F indep A given ('D', 'E', 'B')
# F indep A given ('D', 'C', 'B')
# F indep A given ('E', 'C', 'B')
# F indep A given ('D', 'E', 'C', 'B')
# E indep D given ('A', 'B')
# E indep D given ('B', 'C')
# E indep D given ('A', 'B', 'C')
# E indep D given ('A', 'B', 'F')
# E indep D given ('B', 'C', 'F')
# E indep D given ('A', 'B', 'C', 'F')
# E indep A given ('C', 'B')
# E indep A given ('D', 'C', 'B')
# E indep A given ('C', 'F', 'B')
# E indep A given ('D', 'C', 'F', 'B')
# B indep C given ('A',)
# B indep C given ('A', 'D')
# B indep F given ('E',)
# B indep F given ('A', 'E')
# B indep F given ('D', 'E')
# B indep F given ('E', 'C')
# B indep F given ('A', 'D', 'E')
# B indep F given ('A', 'E', 'C')
# B indep F given ('D', 'E', 'C')
# B indep F given ('A', 'D', 'E', 'C')
# A indep F given ('E',)
# A indep F given ('D', 'E')
# A indep F given ('E', 'C')
# A indep F given ('E', 'B')
# A indep F given ('C', 'B')
# A indep F given ('D', 'E', 'C')
# A indep F given ('D', 'E', 'B')
# A indep F given ('D', 'C', 'B')
# A indep F given ('E', 'C', 'B')
# A indep F given ('D', 'E', 'C', 'B')
# A indep E given ('C', 'B')
# A indep E given ('D', 'C', 'B')
# A indep E given ('C', 'F', 'B')
# A indep E given ('D', 'C', 'F', 'B')
